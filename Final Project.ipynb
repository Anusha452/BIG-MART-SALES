# %% [markdown]
# # Understanding the Data

# %%
#importing the Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#load the dataset
df=pd.read_csv('train Bigmart.csv')
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df['Item_Outlet_Sales'].value_counts()
# Out:
# 958.7520     17
# 1342.2528    16
# 703.0848     15
# 1845.5976    15
# 1278.3360    14
#              ..
# 4124.6310     1
# 6622.7126     1
# 1614.5650     1
# 5602.7070     1
# 2778.3834     1
# Name: Item_Outlet_Sales, Length: 3493, dtype: int64

# %%
df['Item_Visibility'].value_counts()
# Out:
# 0.000000    526
# 0.076975      3
# 0.162462      2
# 0.076841      2
# 0.073562      2
#            ...
# 0.013957      1
# 0.110460      1
# 0.124646      1
# 0.054142      1
# 0.044878      1
# Name: Item_Visibility, Length: 7880, dtype: int64

# %%
df['Item_MRP'].value_counts()
# Out:
# 172.0422    7
# 170.5422    6
# 196.5084    6
# 188.1872    6
# 142.0154    6
#            ..
# 97.3384     1
# 83.1934     1
# 96.6752     1
# 152.6682    1
# 75.4670     1
# Name: Item_MRP, Length: 5938, dtype: int64

# %%
df['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# # Data visualization

# %%
df.plot(kind='scatter', x='Item_Weight', y='Item_Visibility',color='red')
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Item_Visibility'>

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x = 'Item_Weight', y = 'Item_Visibility', hue = 'Outlet_Size', data = df)
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Item_Visibility'>

# %%
sns.scatterplot(x = 'Item_MRP', y = 'Item_Weight', data = df, hue ='Outlet_Size')
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Item_Weight'>

# %%
plt.figure(figsize=(5,5))
plt.hist(x = 'Item_Weight', data = df)
plt.xlabel("Item_Weight")
plt.ylabel("frequency")
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.hist(x = 'Item_MRP', data = df)
plt.xlabel("Item_MRP")
plt.ylabel("Item_Weight")
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.hist(x = 'Item_MRP', data = df)
plt.xlabel("Item_MRP")
plt.ylabel("Outlet_Establishment_Year")
plt.show()

# %%
sns.pairplot(df,hue='Outlet_Size')
plt.show()

# %%
df.plot(kind = "box", figsize = (5,5), rot = 90)
# Out:
# <AxesSubplot:>

# %%
df_n = df.select_dtypes(include= [np.number])
q1 = df_n.quantile(0.25)
q3 = df_n.quantile(0.75)
iqr = q3 - q1

lb = q1 - (1.5*iqr)
ub = q3 + (1.5*iqr)
outliers = df_n[(df_n < lb) | (df_n > ub)]

# %%
outliers.count()
# Out:
# Item_Weight                    0
# Item_Visibility              144
# Item_MRP                       0
# Outlet_Establishment_Year      0
# Item_Outlet_Sales            186
# dtype: int64

# %%
for col in df_n.columns:
    col_median = df_n[col].median()
    df_n.loc[df_n[col] < lb[col], col] = col_median
    df_n.loc[df_n[col] > ub[col], col] = col_median

# %%
outliers_ai = df_n[(df_n < lb) | (df_n > ub)]

# %%
outliers_ai.count()
# Out:
# Item_Weight                  0
# Item_Visibility              0
# Item_MRP                     0
# Outlet_Establishment_Year    0
# Item_Outlet_Sales            0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
cat_col = ['Item_Fat_Content','Outlet_Size','Outlet_Location_Type','Outlet_Type']

# %%
for col in cat_col:
    df[col] = le.fit_transform(df[col].astype(str))

# %%
df
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300                 1         0.016047
# 1              DRC01        5.920                 2         0.019278
# 2              FDN15       17.500                 1         0.016760
# 3              FDX07       19.200                 2         0.000000
# 4              NCD19        8.930                 1         0.000000
# ...              ...          ...               ...              ...
# 8518           FDF22        6.865                 1         0.056783
# 8519           FDS36        8.380                 2         0.046982
# 8520           NCJ29       10.600                 1         0.035186
# 8521           FDN46        7.210                 2         0.145221
# 8522           DRG01       14.800                 1         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.drop(columns = ['Item_Identifier','Item_Type','Outlet_Identifier','Outlet_Establishment_Year'], inplace = True)

# %%
df
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  Outlet_Size  \
# 0           9.300                 1         0.016047  249.8092            1
# 1           5.920                 2         0.019278   48.2692            1
# 2          17.500                 1         0.016760  141.6180            1
# 3          19.200                 2         0.000000  182.0950            3
# 4           8.930                 1         0.000000   53.8614            0
# ...           ...               ...              ...       ...          ...
# 8518        6.865                 1         0.056783  214.5218            0
# 8519        8.380                 2         0.046982  108.1570            3
# 8520       10.600                 1         0.035186   85.1224            2
# 8521        7.210                 2         0.145221  103.1332            1
# 8522       14.800                 1         0.044878   75.4670            2
#
# ...

# %%
df.isnull().sum()
# Out:
# Item_Weight             1463
# Item_Fat_Content           0
# Item_Visibility            0
# Item_MRP                   0
# Outlet_Size                0
# Outlet_Location_Type       0
# Outlet_Type                0
# Item_Outlet_Sales          0
# dtype: int64

# %%
df.fillna(df.mean(), inplace = True)

# %%
df.isnull().sum()
# Out:
# Item_Weight             0
# Item_Fat_Content        0
# Item_Visibility         0
# Item_MRP                0
# Outlet_Size             0
# Outlet_Location_Type    0
# Outlet_Type             0
# Item_Outlet_Sales       0
# dtype: int64

# %%
df
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  Outlet_Size  \
# 0           9.300                 1         0.016047  249.8092            1
# 1           5.920                 2         0.019278   48.2692            1
# 2          17.500                 1         0.016760  141.6180            1
# 3          19.200                 2         0.000000  182.0950            3
# 4           8.930                 1         0.000000   53.8614            0
# ...           ...               ...              ...       ...          ...
# 8518        6.865                 1         0.056783  214.5218            0
# 8519        8.380                 2         0.046982  108.1570            3
# 8520       10.600                 1         0.035186   85.1224            2
# 8521        7.210                 2         0.145221  103.1332            1
# 8522       14.800                 1         0.044878   75.4670            2
#
# ...

# %%
x = df.drop(columns='Item_Outlet_Sales')
y = df['Item_Outlet_Sales']

# %%
x.shape
# Out:
# (8523, 7)

# %%
y.shape
# Out:
# (8523,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state= 10)

# %%
X_train.shape, y_train.shape
# Out:
# ((5966, 7), (5966,))

# %%
X_test.shape , y_test.shape
# Out:
# ((2557, 7), (2557,))

# %%
plt.figure(figsize=(15,15))
sns.heatmap(x.corr(),annot=True)
plt.show()

# %%
#Scaling
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
col=x.columns
col
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
x_fit=s.fit_transform(x)
x_fit
# Out:
# array([[-0.84187169, -0.57284357, -0.97073217, ..., -0.74445778,
#         -1.36933384, -0.25265831],
#        [-1.64170589,  0.97809218, -0.90811123, ..., -0.74445778,
#          1.09156913,  1.00297245],
#        [ 1.09855449, -0.57284357, -0.95691733, ..., -0.74445778,
#         -1.36933384, -0.25265831],
#        ...,
#        [-0.53424315, -0.57284357, -0.59978449, ...,  0.26653866,
#         -0.13888236, -0.25265831],
#        [-1.33644372,  0.97809218,  1.53287976, ..., -0.74445778,
#          1.09156913,  1.00297245],
#        [ 0.45963367, -0.57284357, -0.41193591, ...,  0.26653866,
#         -1.36933384, -0.25265831]])

# %%
x=pd.DataFrame(x_fit,columns=col)
x
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  Outlet_Size  \
# 0       -0.841872         -0.572844        -0.970732  1.747454    -0.744458
# 1       -1.641706          0.978092        -0.908111 -1.489023    -0.744458
# 2        1.098554         -0.572844        -0.956917  0.010040    -0.744458
# 3        1.500838          0.978092        -1.281758  0.660050     1.277535
# 4       -0.929428         -0.572844        -1.281758 -1.399220    -1.755454
# ...           ...               ...              ...       ...          ...
# 8518    -1.418084         -0.572844        -0.181193  1.180783    -1.755454
# 8519    -1.059578          0.978092        -0.371154 -0.527301     1.277535
# 8520    -0.534243         -0.572844        -0.599784 -0.897208     0.266539
# 8521    -1.336444          0.978092         1.532880 -0.607977    -0.744458
# 8522     0.459634         -0.572844        -0.411936 -1.052261     0.266539
#
#       Outlet_Location_Type  Outlet_Type
# ...

# %% [markdown]
# # Linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()

# %%
LR.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
LR.intercept_
# Out:
# -805.5394488231782

# %%
LR.coef_
# Out:
# array([ 7.38953738e-01,  2.85238741e+01, -1.78788567e+03,  1.55440598e+01,
#        -1.08640046e+01, -2.46223385e+02,  9.68240074e+02])

# %%
LR.score(X_train,y_train)
# Out:
# 0.5007375702394874

# %%
LR.score(X_test,y_test)
# Out:
# 0.49704937933628823

# %%
from sklearn.model_selection import cross_val_score

# %%
scores=cross_val_score(LR,x,y,cv=5)
print(scores)
cv_score=scores.mean()
print(cv_score)
# Out:
# [0.51341525 0.50513094 0.48127542 0.49664905 0.49500077]
# 0.49829428422601635

# %%
p_values = LR.predict(X_test)
p = pd.DataFrame({'actual_value': y_test, 'predicted_value': p_values})
p
# Out:
#       actual_value  predicted_value
# 7186     3649.2498      4146.862204
# 2283     1845.5976      1659.649411
# 2206     2675.1844      2788.939654
# 5446      675.7870      2151.228572
# 6380     3755.1120      2796.533325
# ...            ...              ...
# 475      1193.1136      1272.072378
# 2189     5243.8408      3503.817142
# 8235      551.2824      1315.141266
# 3341      299.6100      -216.258816
# 5855     3554.7062      2777.716351
#
# [2557 rows x 2 columns]

# %%
from sklearn.metrics import r2_score

# %%
r_value1= r2_score(y_test, p_values)
r_value1
# Out:
# 0.49704937933628823

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
RF=RandomForestRegressor()
RF.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
scores=cross_val_score(RF,x,y,cv=5)
print(scores)
cv_score=scores.mean()
print(cv_score)
# Out:
# [0.56352317 0.53296922 0.52052369 0.54481188 0.56024477]
# 0.5444145462763796

# %%
p_values = RF.predict(X_test)
p = pd.DataFrame({'actual_value': y_test, 'predicted_value': p_values})
p
# Out:
#       actual_value  predicted_value
# 7186     3649.2498      4741.594570
# 2283     1845.5976      2038.353358
# 2206     2675.1844      2131.924890
# 5446      675.7870      1705.440042
# 6380     3755.1120      3024.895850
# ...            ...              ...
# 475      1193.1136      1244.293646
# 2189     5243.8408      3866.167440
# 8235      551.2824       535.296542
# 3341      299.6100       162.967866
# 5855     3554.7062      3167.723266
#
# [2557 rows x 2 columns]

# %%
r_value2= r2_score(y_test, p_values)
r_value2
# Out:
# 0.5353006791452658

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
DT=DecisionTreeRegressor()
DT.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
scores=cross_val_score(DT,x,y,cv=5)
print(scores)
cv_score=scores.mean()
print(cv_score)
# Out:
# [0.2822267  0.1977344  0.13480358 0.21389708 0.20274326]
# 0.20628100411866052

# %%
p_values = DT.predict(X_test)
p = pd.DataFrame({'actual_value': y_test, 'predicted_value': p_values})
p
# Out:
#       actual_value  predicted_value
# 7186     3649.2498        6183.9504
# 2283     1845.5976        2090.6120
# 2206     2675.1844        2656.5420
# 5446      675.7870        2678.5134
# 6380     3755.1120        2065.3116
# ...            ...              ...
# 475      1193.1136        1022.6688
# 2189     5243.8408        4655.2736
# 8235      551.2824         882.1850
# 3341      299.6100         123.8388
# 5855     3554.7062        3592.6568
#
# [2557 rows x 2 columns]

# %%
r_value3= r2_score(y_test, p_values)
r_value3
# Out:
# 0.15531282040576644

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
KN=KNeighborsRegressor(n_neighbors=5)
KN.fit(x,y)
# Out:
# KNeighborsRegressor()

# %%
scores=cross_val_score(KN,x,y,cv=5)
print(scores)
cv_score=scores.mean()
print(cv_score)
# Out:
# [0.51647458 0.52869304 0.49251687 0.52347323 0.54371751]
# 0.5209750431970469

# %%
p_values = KN.predict(X_test)
p = pd.DataFrame({'actual_value': y_test, 'predicted_value': p_values})
p
# Out:
#       actual_value  predicted_value
# 7186     3649.2498       3391.85152
# 2283     1845.5976       3073.86544
# 2206     2675.1844       3073.86544
# 5446      675.7870       4745.55608
# 6380     3755.1120       3550.84456
# ...            ...              ...
# 475      1193.1136       4432.49692
# 2189     5243.8408       3550.84456
# 8235      551.2824       3550.84456
# 3341      299.6100       4432.49692
# 5855     3554.7062       3550.84456
#
# [2557 rows x 2 columns]

# %%
r_value4= r2_score(y_test, p_values)
r_value4
# Out:
# -1.2754352772684774

# %% [markdown]
# # XGB

# %%
pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBRegressor
XGB=XGBRegressor()
XGB.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
scores=cross_val_score(XGB,x,y,cv=5)
print(scores)
cv_score=scores.mean()
print(cv_score)
# Out:
# [0.55252884 0.52198533 0.49639888 0.52446889 0.55596557]
# 0.5302695029726822

# %%
p_values = XGB.predict(X_test)
p = pd.DataFrame({'actual_value': y_test, 'predicted_value': p_values})
p
# Out:
#       actual_value  predicted_value
# 7186     3649.2498      5283.488281
# 2283     1845.5976      1573.756836
# 2206     2675.1844      2682.336182
# 5446      675.7870      1606.557617
# 6380     3755.1120      2880.756592
# ...            ...              ...
# 475      1193.1136      1457.441528
# 2189     5243.8408      3850.003418
# 8235      551.2824       240.833710
# 3341      299.6100       148.464127
# 5855     3554.7062      3042.652100
#
# [2557 rows x 2 columns]

# %%
r_value5= r2_score(y_test, p_values)
r_value5
# Out:
# 0.522332645916399

# %%
#r2_score of Linear regression = 0.49
#r2_score of Random Forest = 0.53
#r2_score of Decision Tree = 0.14
#r2_score of KNN = -1.27
#r2_score of XGB = 0.52
